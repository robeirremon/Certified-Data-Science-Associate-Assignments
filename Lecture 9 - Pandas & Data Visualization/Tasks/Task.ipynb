# %% [markdown]
# ##  Data Analyst (Pandas)

# %%
import numpy as np
import pandas as pd

# %%
my_list = np.random.randn(100,4)
#my_list

# %%
my_columns=['X','Y','Z','S']

# %%
df=pd.DataFrame(data=my_list,columns=my_columns)
df
# Out:
#            X         Y         Z         S
# 0  -0.790418 -0.684461  0.494294  0.793853
# 1   1.050818 -0.581697  0.384717 -1.432218
# 2  -0.737648 -1.393556 -0.097360  1.564029
# 3   1.180597 -0.170280 -1.572435  0.496032
# 4  -1.147064  0.100782 -0.877188  0.448294
# ..       ...       ...       ...       ...
# 95 -2.799444 -0.267460  0.938101  0.144339
# 96 -1.258646  0.238290  0.468083  1.398918
# 97  0.794296  1.176853  0.295212 -0.980868
# 98 -0.551678  0.392124 -0.423954 -0.810275
# 99 -1.175178  1.137946 -0.696035 -0.616949
#
# [100 rows x 4 columns]

# %%
df[(df['Z'] > 0) & (df['X'] < 0)]['S'].iloc[3:9]
# Out:
# 14    1.330808
# 20    1.344607
# 23    1.520680
# 40    0.449226
# 41   -0.503811
# 43   -1.098913
# Name: S, dtype: float64

# %%
df.iloc[3:9][(df['Z'] > 0) & (df['X'] < 0)]['S']
# Out:
# C:\Users\Robeir\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 5    0.004556
# Name: S, dtype: float64

# %% [markdown]
# # csv file

# %%
df2=pd.read_csv('Ecommerce Purchases.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
#  14  mail_vendor       10000 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 1.1+ MB

# %%
df2['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
df2['Purchase Price'].describe()
# Out:
# count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: Purchase Price, dtype: float64

# %%
def extract_mail(text):
    _,txt=text.split('@')
    return txt

# %%
df2['mail_vendor'] = df2['Email'].apply(extract_mail)

# %%
df2['mail_vendor'].value_counts()
# Out:
# hotmail.com               1638
# yahoo.com                 1616
# gmail.com                 1605
# smith.com                   42
# williams.com                37
#                           ...
# henderson-peterson.org       1
# sloan.com                    1
# randall-villarreal.com       1
# campos.info                  1
# harris-wall.org              1
# Name: mail_vendor, Length: 3416, dtype: int64

# %%
df2
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# ## Data Visualization (Seaborn)

# %%
import seaborn as sns

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
#  14  mail_vendor       10000 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 1.1+ MB

# %%
df2['X'] = df2['Lot'].apply(lambda x : int(x.split()[0]))

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
#  14  mail_vendor       10000 non-null  object
#  15  X                 10000 non-null  int64
# ...

# %%
sns.distplot(df2['X'],kde=False,color='m')

# %%
sns.distplot(df2['Purchase Price'])

# %%
sns.kdeplot(df2['X'], shade=True, color='m')

# %%
sns.jointplot(x='X', y='Purchase Price', data=df2, kind='scatter')

# %%
sns.jointplot(x='X', y='Purchase Price', data=df2, kind='kde')

# %%
sns.pairplot(df2)
